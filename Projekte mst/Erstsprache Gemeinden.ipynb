# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
path1 = "Erstsprache/Erstsprache nach Schulstufe_2017.xls"
path2 = "Erstsprache/Erstsprache nach Schulstufe_2016.xls"

# %%
df1 = pd.read_excel(path1, skiprows=[0,1,2,3])
df2 = pd.read_excel(path2, skiprows=[0,1,2,3])

# %%
df1
# Out:
#       Jahr                         Schulgemeinde  \
# 0     2017                      Adlikon (Primar)
# 1     2017                      Adlikon (Primar)
# 2     2017                      Adlikon (Primar)
# 3     2017           Adliswil (Einheitsgemeinde)
# 4     2017           Adliswil (Einheitsgemeinde)
# ...    ...                                   ...
# 4592  2017  Zürich-Zürichberg (Kreisschulpflege)
# 4593  2017  Zürich-Zürichberg (Kreisschulpflege)
# 4594  2017  Zürich-Zürichberg (Kreisschulpflege)
# 4595  2017  Zürich-Zürichberg (Kreisschulpflege)
# 4596  2017  Zürich-Zürichberg (Kreisschulpflege)
#
#                          Erstsprache    KG    PS  PS Sonder  Sek A  Sek B  \
# 0                            Deutsch   0.0  12.0        0.0    NaN    NaN
# 1                           Kurdisch   0.0   2.0        0.0    NaN    NaN
# 2      Übrige ostasiatische Sprachen   0.0   1.0        0.0    NaN    NaN
# 3                          Albanisch  27.0  78.0        1.0   13.0   15.0
# ...

# %%
df2
# Out:
#       Jahr                         Schulgemeinde  \
# 0     2016                      Adlikon (Primar)
# 1     2016                      Adlikon (Primar)
# 2     2016           Adliswil (Einheitsgemeinde)
# 3     2016           Adliswil (Einheitsgemeinde)
# 4     2016           Adliswil (Einheitsgemeinde)
# ...    ...                                   ...
# 4527  2016  Zürich-Zürichberg (Kreisschulpflege)
# 4528  2016  Zürich-Zürichberg (Kreisschulpflege)
# 4529  2016  Zürich-Zürichberg (Kreisschulpflege)
# 4530  2016  Zürich-Zürichberg (Kreisschulpflege)
# 4531  2016  Zürich-Zürichberg (Kreisschulpflege)
#
#                          Erstsprache    KG    PS  PS Sonder  Sek A  Sek B  \
# 0                            Deutsch   0.0  12.0        0.0    NaN    NaN
# 1      Übrige ostasiatische Sprachen   0.0   1.0        0.0    NaN    NaN
# 2                          Albanisch  23.0  82.0        0.0   13.0   13.0
# 3                           Arabisch   6.0   4.0        1.0    0.0    0.0
# ...

# %%
df1.dtypes
# Out:
# Jahr               int64
# Schulgemeinde     object
# Erstsprache       object
# KG               float64
# PS               float64
# PS Sonder        float64
# Sek A            float64
# Sek B            float64
# Sek C            float64
# Sek Sonder       float64
# Total              int64
# dtype: object

# %%
df2.dtypes
# Out:
# Jahr               int64
# Schulgemeinde     object
# Erstsprache       object
# KG               float64
# PS               float64
# PS Sonder        float64
# Sek A            float64
# Sek B            float64
# Sek C            float64
# Sek Sonder       float64
# Total              int64
# dtype: object

# %%
df1.shape
# Out:
# (4597, 11)

# %%
df2.shape
# Out:
# (4532, 11)

# %%
df1.describe()
# Out:
#          Jahr           KG           PS    PS Sonder        Sek A  \
# count  4597.0  3904.000000  3904.000000  3904.000000  3032.000000
# mean   2017.0     7.760246    21.190318     0.127305     5.681069
# std       0.0    34.818558    95.624840     0.718649    23.473752
# min    2017.0     0.000000     0.000000     0.000000     0.000000
# 25%    2017.0     0.000000     1.000000     0.000000     0.000000
# 50%    2017.0     1.000000     3.000000     0.000000     1.000000
# 75%    2017.0     3.000000     9.000000     0.000000     2.000000
# max    2017.0   849.000000  2425.000000    13.000000   386.000000
#
#              Sek B        Sek C   Sek Sonder        Total
# count  3032.000000  3032.000000  3032.000000  4597.000000
# mean      3.754947     0.574208     0.113127    31.371329
# std      10.071485     2.063756     1.337749   140.386038
# min       0.000000     0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     0.000000     2.000000
# ...

# %%
df2.describe()
# Out:
#          Jahr           KG           PS    PS Sonder        Sek A  \
# count  4532.0  3843.000000  3843.000000  3843.000000  2972.000000
# mean   2016.0     7.782462    21.040853     0.140515     5.630552
# std       0.0    35.738451    92.070092     0.721161    23.005804
# min    2016.0     0.000000     0.000000     0.000000     0.000000
# 25%    2016.0     0.000000     1.000000     0.000000     0.000000
# 50%    2016.0     1.000000     3.000000     0.000000     1.000000
# 75%    2016.0     3.000000     9.000000     0.000000     2.000000
# max    2016.0   873.000000  2259.000000    12.000000   367.000000
#
#              Sek B        Sek C   Sek Sonder        Total
# count  2972.000000  2972.000000  2972.000000  4532.000000
# mean      3.847577     0.592530     0.138964    31.255737
# std      10.480511     2.082896     1.284714   137.375635
# min       0.000000     0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     0.000000     2.000000
# ...

# %%
df1['KG'].value_counts().sort_index()
# Out:
# 0.0      1438
# 1.0       911
# 2.0       396
# 3.0       233
# 4.0       156
#          ...
# 553.0       1
# 601.0       1
# 622.0       1
# 745.0       1
# 849.0       1
# Name: KG, Length: 133, dtype: int64

# %%
df2['KG'].value_counts().sort_index()
# Out:
# 0.0      1404
# 1.0       907
# 2.0       384
# 3.0       248
# 4.0       145
#          ...
# 521.0       1
# 622.0       1
# 722.0       1
# 758.0       1
# 873.0       1
# Name: KG, Length: 137, dtype: int64

# %%
df_new = df1.merge(df2, how='inner', on='KG')
df_new.head(20)
# Out:
#     Jahr_x   Schulgemeinde_x Erstsprache_x   KG  PS_x  PS Sonder_x  Sek A_x  \
# 0     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 1     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 2     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 3     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 4     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 5     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 6     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 7     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 8     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 9     2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# 10    2017  Adlikon (Primar)       Deutsch  0.0  12.0          0.0      NaN
# ...

# %%
df = pd.read_excel(path, na_values= {'KG',"PS","PS Sonder","Sek A","Sek B","Sek C","Sek Sonder","Total"})

# %%
df.dtypes
# Out:
# Erstsprache nach Schulstufe     object
# Unnamed: 1                      object
# Unnamed: 2                      object
# Unnamed: 3                     float64
# Unnamed: 4                     float64
# Unnamed: 5                     float64
# Unnamed: 6                     float64
# Unnamed: 7                     float64
# Unnamed: 8                     float64
# Unnamed: 9                     float64
# Unnamed: 10                    float64
# dtype: object

# %%
df['Unnamed: 1'].unique()
# Out:
# array([nan, 'Schulgemeinde', 'Adlikon (Primar)',
#        'Adliswil (Einheitsgemeinde)', 'Aesch (Primar)',
#        'Aeugst a.A. (Primar)', 'Affoltern a.A. (Primar)',
#        'Affoltern a.A.-Aeugst (Sekundar)', 'Altikon (Primar + Pol. Gem.)',
#        'Andelfingen (Primar)', 'Andelfingen (Sekundar)',
#        'Bachenbülach (Primar)', 'Bachs (Primar)',
#        'Bäretswil (Einheitsgemeinde)', 'Bassersdorf (Einheitsgemeinde)',
#        'Bauma-Sternenberg (Einheitsgemeinde)', 'Benken (Primar)',
#        'Birmensdorf (Primar)', 'Birmensdorf-Aesch (Sekundar)',
#        'Bonstetten (Primar + Pol. Gem.)', 'Bonstetten (Sekundar)',
#        'Boppelsen (Primar)', 'Brütten (Einheitsgemeinde)',
#        'Bubikon (Primar + Sekundar)', 'Buchs (Primar + Pol. Gem.)',
#        'Bülach (Primar + Pol. Gem.)', 'Bülach (Sekundar)',
#        'Dachsen (Primar)', 'Dägerlen (Primar)',
#        'Dällikon (Primar + Pol. Gem.)', 'Dänikon-Hüttikon (Primar)',
# ...

# %%
df.sort_values('Unnamed: 3', ascending=False).head(20)
# Out:
#      Erstsprache nach Schulstufe  \
# 4523                        2017
# 4480                        2017
# 4322                        2017
# 4566                        2017
# 3513                        2017
# 4363                        2017
# 4404                        2017
# 4071                        2017
# 4190                        2017
# 4113                        2017
# 4153                        2017
# 3622                        2017
# 3936                        2017
# 4444                        2017
# 2012                        2017
# 3264                        2017
# 2581                        2017
# 2751                        2017
# 3584                        2017
# 1629                        2017
#
#                                              Unnamed: 1 Unnamed: 2  \
# 4523                 Zürich-Waidberg (Kreisschulpflege)    Deutsch
# 4480                      Zürich-Uto (Kreisschulpflege)    Deutsch
# ...

# %%
df[df['Unnamed: 1'] == {"Adliswil (Einheitsgemeinde)",
   "Wädenswil (Primar + Pol. Gem.)"}].sort_values('Unnamed: 3', ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-550e670088b1> in <module>
# ----> 1 df[df['Unnamed: 1'] == {"Adliswil (Einheitsgemeinde)",
#       2    "Wädenswil (Primar + Pol. Gem.)"}].sort_values('Unnamed: 3', ascending=False).head()
#
# NameError: name 'df' is not defined

# %%
seegemeinden = df['Unnamed: 1'] == {"Adliswil (Einheitsgemeinde)","Wädenswil (Primar + Pol. Gem.)"}

# %%
df[seegemeinden]
# Out:
# Empty DataFrame
# Columns: [Erstsprache nach Schulstufe, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10]
# Index: []

# %%
df[seegemeinden].sort_values('Unnamed: 3', ascending=False).head(10)
# Out:
# Empty DataFrame
# Columns: [Erstsprache nach Schulstufe, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10]
# Index: []

# %%
df.rename(columns={"Unnamed: 1": "Schulgemeinde","Unnamed: 2": "Sprache",
                   'Unnamed: 3': 'Kindergarten','Unnamed: 4': 'Primarschule',
                   "Unnamed: 5":"Primar Sonder","Unnamed: 6":"Sek A"})
# Out:
#                            Erstsprache nach Schulstufe  \
# 0     Stand: 02.10.2019 / Bildungsstatistik Kanton zh]
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Jahr
# 4                                                 2017
# ...                                                ...
# 4596                                              2017
# 4597                                              2017
# 4598                                              2017
# 4599                                              2017
# 4600                                              2017
#
#                              Schulgemeinde                         Sprache  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# ...
