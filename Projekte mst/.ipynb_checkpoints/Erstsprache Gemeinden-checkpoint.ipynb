# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
path = "Erstsprache/Erstsprache nach Schulstufe_2017.xls"

# %%
df = pd.read_excel(path)

# %%
df
# Out:
#                            Erstsprache nach Schulstufe  \
# 0     Stand: 02.10.2019 / Bildungsstatistik Kanton zh]
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Jahr
# 4                                                 2017
# ...                                                ...
# 4596                                              2017
# 4597                                              2017
# 4598                                              2017
# 4599                                              2017
# 4600                                              2017
#
#                                 Unnamed: 1                      Unnamed: 2  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# ...

# %%
df.dtypes
# Out:
# Erstsprache nach Schulstufe    object
# Unnamed: 1                     object
# Unnamed: 2                     object
# Unnamed: 3                     object
# Unnamed: 4                     object
# Unnamed: 5                     object
# Unnamed: 6                     object
# Unnamed: 7                     object
# Unnamed: 8                     object
# Unnamed: 9                     object
# Unnamed: 10                    object
# dtype: object

# %%
df.shape
# Out:
# (4601, 11)

# %%
df.describe()
# Out:
#         Erstsprache nach Schulstufe                          Unnamed: 1  \
# count                          4599                                4598
# unique                            3                                 195
# top                            2017  Zürich-Waidberg (Kreisschulpflege)
# freq                           4597                                  45
#
#        Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# count        4598        3905        3905        3905        3033        3033
# unique         47         134         227          14         111          76
# top       Deutsch           0           1           0           0           0
# freq          194        1438         912        3681        1369        1418
#
#         Unnamed: 8  Unnamed: 9  Unnamed: 10
# count         3033        3033         4598
# unique          24          13          303
# top              0           0            1
# ...

# %%
df['Unnamed: 1'].value_counts().sort_index()
# Out:
# Adlikon (Primar)                             3
# Adliswil (Einheitsgemeinde)                 36
# Aesch (Primar)                               8
# Aeugst a.A. (Primar)                        12
# Affoltern a.A. (Primar)                     29
#                                             ..
# Zürich-Limmattal (Kreisschulpflege)         40
# Zürich-Schwamendingen (Kreisschulpflege)    36
# Zürich-Uto (Kreisschulpflege)               43
# Zürich-Waidberg (Kreisschulpflege)          45
# Zürich-Zürichberg (Kreisschulpflege)        39
# Name: Unnamed: 1, Length: 195, dtype: int64

# %%
df = pd.read_excel(path, na_values= {'KG',"PS","PS Sonder","Sek A","Sek B","Sek C","Sek Sonder","Total"})

# %%
df.dtypes
# Out:
# Erstsprache nach Schulstufe     object
# Unnamed: 1                      object
# Unnamed: 2                      object
# Unnamed: 3                     float64
# Unnamed: 4                     float64
# Unnamed: 5                     float64
# Unnamed: 6                     float64
# Unnamed: 7                     float64
# Unnamed: 8                     float64
# Unnamed: 9                     float64
# Unnamed: 10                    float64
# dtype: object

# %%
df.sort_values('Unnamed: 3', ascending=False).tail(10)
# Out:
#      Erstsprache nach Schulstufe                     Unnamed: 1  \
# 3991                        2017  Wetzikon-Seegräben (Sekundar)
# 3992                        2017  Wetzikon-Seegräben (Sekundar)
# 3993                        2017  Wetzikon-Seegräben (Sekundar)
# 4027                        2017                Wila (Sekundar)
# 4028                        2017                Wila (Sekundar)
# 4029                        2017                Wila (Sekundar)
# 4030                        2017                Wila (Sekundar)
# 4031                        2017                Wila (Sekundar)
# 4032                        2017                Wila (Sekundar)
# 4033                        2017                Wila (Sekundar)
#
#                           Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 3991                 Übrige Sprachen         NaN         NaN         NaN
# 3992  Übrige westasiatische Sprachen         NaN         NaN         NaN
# ...

# %%
df[df['Unnamed: 1'] == 'Adliswil (Einheitsgemeinde)'].sort_values('Unnamed: 3', ascending=False).head(10)
# Out:
#    Erstsprache nach Schulstufe                   Unnamed: 1  \
# 13                        2017  Adliswil (Einheitsgemeinde)
# 14                        2017  Adliswil (Einheitsgemeinde)
# 7                         2017  Adliswil (Einheitsgemeinde)
# 19                        2017  Adliswil (Einheitsgemeinde)
# 28                        2017  Adliswil (Einheitsgemeinde)
# 40                        2017  Adliswil (Einheitsgemeinde)
# 24                        2017  Adliswil (Einheitsgemeinde)
# 25                        2017  Adliswil (Einheitsgemeinde)
# 33                        2017  Adliswil (Einheitsgemeinde)
# 42                        2017  Adliswil (Einheitsgemeinde)
#
#             Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 13             Deutsch       170.0       459.0         0.0        90.0
# 14            Englisch        36.0        70.0         0.0        10.0
# 7            Albanisch        27.0        78.0         1.0        13.0
# ...
