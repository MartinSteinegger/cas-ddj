# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = "Bilanz Winterthur/fpzuerich_01-10-2019_10-51.xlsx"

# %%
df = pd.read_excel(path)

# %%
df.tail(30)
# Out:
#     GEFIS_EINHEIT                                       GEBIETS_NAME  \
# 217      882000PP                        Wädenswil, Stadt (bis 2018)
# 218      863600PS                          Wald, Politische Gemeinde
# 219       863600P               Wald, Politische Gemeinde (bis 2010)
# 220       830400P                   Wallisellen, Politische Gemeinde
# 221       846800P        Waltalingen, Politische Gemeinde (bis 2018)
# 222      830600PS           Wangen-Brüttisellen, Politische Gemeinde
# 223       830600P  Wangen-Brüttisellen, Politische Gemeinde (bis ...
# 224       819500P                  Wasterkingen, Politische Gemeinde
# 225       818700P                        Weiach, Politische Gemeinde
# 226      810400PP                     Weiningen, Politische Gemeinde
# 227       810400P          Weiningen, Politische Gemeinde (bis 2006)
# 228      848400PS                   Weisslingen, Politische Gemeinde
# 229       848400P        Weisslingen, Politische Gemeinde (bis 2006)
# ...

# %%
df.dtypes
# Out:
# GEFIS_EINHEIT      object
# GEBIETS_NAME       object
# INDIKATOR_NAME     object
# 2018              float64
# 2017              float64
# 2016              float64
# 2015              float64
# 2014              float64
# 2013              float64
# 2012              float64
# 2011              float64
# 2010              float64
# 2009              float64
# 2008              float64
# 2007              float64
# 2006              float64
# 2005              float64
# 2004              float64
# 2003              float64
# 2002              float64
# 2001              float64
# 2000              float64
# 1999              float64
# 1998              float64
# 1997              float64
# 1996              float64
# 1995              float64
# 1994              float64
# 1993              float64
# 1992              float64
# 1991              float64
# 1990              float64
# dtype: object

# %%
df.shape
# Out:
# (247, 32)

# %%
df[df["GEBIETS_NAME"] == 'Winterthur, Stadt']
# Out:
#     GEFIS_EINHEIT       GEBIETS_NAME  \
# 240      840000PS  Winterthur, Stadt
#
#                                         INDIKATOR_NAME        2018  \
# 240  91 Ertragsüberschuss (+) / Aufwandüberschuss (...  37026575.0
#
#            2017        2016        2015        2014       2013       2012  \
# 240  56485637.0 -97095424.0  12722825.0  16446242.0  1715105.0  4093865.0
#
#      ...       1999       1998        1997       1996       1995       1994  \
# 240  ... -6780717.0 -6628985.0 -10657392.0 -8400805.0 -1409833.0 -1566460.0
#
#           1993        1992        1991       1990
# 240 -1740926.0 -35037356.0 -16132950.0  2724034.0
#
# [1 rows x 32 columns]

# %%
df[df["GEBIETS_NAME"] == 'Wädenswil, Stadt (bis 2018)']
# Out:
#     GEFIS_EINHEIT                 GEBIETS_NAME  \
# 217      882000PP  Wädenswil, Stadt (bis 2018)
#
#                                         INDIKATOR_NAME      2018       2017  \
# 217  91 Ertragsüberschuss (+) / Aufwandüberschuss (... -950585.0  2884330.0
#
#          2016       2015       2014        2013       2012  ...       1999  \
# 217 -424436.0 -6802338.0 -7246648.0  11957627.0 -4949992.0  ...  5652580.0
#
#          1998       1997       1996       1995       1994       1993  \
# 217  540533.0 -2842532.0  1908533.0  5005572.0  5082468.0 -4031571.0
#
#           1992       1991       1990
# 217 -1774278.0 -5153598.0 -3149162.0
#
# [1 rows x 32 columns]

# %%
saubereliste = ['GEBIETS_NAME',1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,
               2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]

# %%
saubereliste
# Out:
# ['GEBIETS_NAME',
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018]

# %%
df[saubereliste]
# Out:
#                                 GEBIETS_NAME         1990         1991  \
# 0               Adlikon, Politische Gemeinde      37630.0     206833.0
# 1                            Adliswil, Stadt     319332.0   -1219798.0
# 2                 Aesch, Politische Gemeinde    -258802.0     -57104.0
# 3           Aeugst a.A., Politische Gemeinde    1343439.0     707713.0
# 4           Affoltern a.A., Stadt (bis 2018)   -1029980.0   -1212219.0
# ..                                       ...          ...          ...
# 242     Zell, Politische Gemeinde (bis 2002)   -1745157.0   -2087025.0
# 243            Zollikon, Politische Gemeinde    8159625.0   -1952680.0
# 244             Zumikon, Politische Gemeinde          NaN          NaN
# 245  Zumikon, Politische Gemeinde (bis 2014)    2632071.0   -3302297.0
# 246                            Zürich, Stadt -113290000.0 -379373000.0
#
#             1992         1993         1994         1995         1996  \
# ...

# %%
df[saubereliste].iloc[240:241]
# Out:
#           GEBIETS_NAME       1990        1991        1992       1993  \
# 240  Winterthur, Stadt  2724034.0 -16132950.0 -35037356.0 -1740926.0
#
#           1994       1995       1996        1997       1998  ...       2009  \
# 240 -1566460.0 -1409833.0 -8400805.0 -10657392.0 -6628985.0  ... -2966750.0
#
#           2010       2011       2012       2013        2014        2015  \
# 240 -2963195.0 -2740765.0  4093865.0  1715105.0  16446242.0  12722825.0
#
#            2016        2017        2018
# 240 -97095424.0  56485637.0  37026575.0
#
# [1 rows x 30 columns]

# %%
winterthur = df[saubereliste].iloc[240:241]

# %%
path = 'Bilanz Winterthur/budgetwinti.csv'

# %%
winterthur.to_csv(path, index=False)

# %%
check = pd.read_csv(path)

# %%
check
# Out:
#         GEBIETS_NAME       1990        1991        1992       1993       1994  \
# 0  Winterthur, Stadt  2724034.0 -16132950.0 -35037356.0 -1740926.0 -1566460.0
#
#         1995       1996        1997       1998  ...       2009       2010  \
# 0 -1409833.0 -8400805.0 -10657392.0 -6628985.0  ... -2966750.0 -2963195.0
#
#         2011       2012       2013        2014        2015        2016  \
# 0 -2740765.0  4093865.0  1715105.0  16446242.0  12722825.0 -97095424.0
#
#          2017        2018
# 0  56485637.0  37026575.0
#
# [1 rows x 30 columns]

# %%
df[saubereliste].iloc[240:241].plot()
# Out:
# /Users/martinsteinegger/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1085: UserWarning: Attempting to set identical left == right == 240.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)

# %%
winti = df[saubereliste].iloc[240]

# %%
winti = winti.drop('GEBIETS_NAME')

# %%
winti.plot()

# %%
winti.hist()

# %%
df_clean = df[saubereliste]

# %%
df_clean['GEBIETS_NAME'].unique()
# Out:
# array(['Adlikon, Politische Gemeinde', 'Adliswil, Stadt',
#        'Aesch, Politische Gemeinde', 'Aeugst a.A., Politische Gemeinde',
#        'Affoltern a.A., Stadt (bis 2018)', 'Altikon, Politische Gemeinde',
#        'Altikon, Politische Gemeinde (bis 2001)',
#        'Andelfingen, Politische Gemeinde',
#        'Bachenbülach, Politische Gemeinde', 'Bachs, Politische Gemeinde',
#        'Bäretswil, Politische Gemeinde',
#        'Bäretswil, Politische Gemeinde (bis 2002)',
#        'Bassersdorf, Politische Gemeinde',
#        'Bassersdorf, Politische Gemeinde (bis 2006)',
#        'Bauma, Politische Gemeinde',
#        'Bauma, Politische Gemeinde (bis 1997)',
#        'Bauma, Politische Gemeinde (bis 2014)',
#        'Benken, Politische Gemeinde', 'Berg a.I., Politische Gemeinde',
#        'Bertschikon, Politische Gemeinde (bis 2011)',
#        'Bertschikon, Politische Gemeinde (bis 2013)',
#        'Birmensdorf, Politische Gemeinde',
#        'Bonstetten, Politische Gemeinde',
# ...

# %%
df_clean[(df_clean['GEBIETS_NAME'] == 'Adliswil, Stadt')\
        | (df_clean['GEBIETS_NAME'] == 'Horgen, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Horgen, Politische Gemeinde (bis 2017)')\
        | (df_clean['GEBIETS_NAME'] == 'Kilchberg, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Oberrieden, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Oberrieden, Politische Gemeinde (bis 2009)')\
        | (df_clean['GEBIETS_NAME'] == 'Richterswil, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Richterswil, Politische Gemeinde (bis 1997)')\
        | (df_clean['GEBIETS_NAME'] == 'Thalwil, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Wädenswil, Stadt (bis 2018)')\
        | (df_clean['GEBIETS_NAME'] == 'Rüschlikon, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Langnau a.A., Politische Gemeinde')]
df_horgen = df_clean[(df_clean['GEBIETS_NAME'] == 'Adliswil, Stadt')\
        | (df_clean['GEBIETS_NAME'] == 'Horgen, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Horgen, Politische Gemeinde (bis 2017)')\
        | (df_clean['GEBIETS_NAME'] == 'Kilchberg, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Oberrieden, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Oberrieden, Politische Gemeinde (bis 2009)')\
        | (df_clean['GEBIETS_NAME'] == 'Richterswil, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Richterswil, Politische Gemeinde (bis 1997)')\
        | (df_clean['GEBIETS_NAME'] == 'Thalwil, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Wädenswil, Stadt (bis 2018)')\
        | (df_clean['GEBIETS_NAME'] == 'Rüschlikon, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Langnau a.A., Politische Gemeinde')]

# %%
df_clean[(df_clean['GEBIETS_NAME'] == 'Erlenbach, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Herrliberg, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Herrliberg, Politische Gemeinde (bis 2006)')\
        | (df_clean['GEBIETS_NAME'] == 'Hombrechtikon, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Hombrechtikon, Politische Gemeinde (bis 2009)')\
        | (df_clean['GEBIETS_NAME'] == 'Küsnacht, Politische Gemeinde (bis 2018)')\
        | (df_clean['GEBIETS_NAME'] == 'Männedorf, Politische Gemeinde (bis 2006)')\
        | (df_clean['GEBIETS_NAME'] == 'Meilen, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Meilen, Politische Gemeinde (bis 2009)')\
        | (df_clean['GEBIETS_NAME'] == 'Oetwil a.d.L., Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Stäfa, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Stäfa, Politische Gemeinde (bis 2014)')\
        | (df_clean['GEBIETS_NAME'] == 'Uetikon am See, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Uetikon am See, Politische Gemeinde (bis 2002)')\
        | (df_clean['GEBIETS_NAME'] == 'Zumikon, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Zumikon, Politische Gemeinde (bis 2014)')\
        | (df_clean['GEBIETS_NAME'] == 'Zollikon, Politische Gemeinde')
        | (df_clean['GEBIETS_NAME'] == 'Männedorf, Politische Gemeinde')]
df_meilen = df_clean[(df_clean['GEBIETS_NAME'] == 'Erlenbach, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Herrliberg, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Herrliberg, Politische Gemeinde (bis 2006)')\
        | (df_clean['GEBIETS_NAME'] == 'Hombrechtikon, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Hombrechtikon, Politische Gemeinde (bis 2009)')\
        | (df_clean['GEBIETS_NAME'] == 'Küsnacht, Politische Gemeinde (bis 2018)')\
        | (df_clean['GEBIETS_NAME'] == 'Männedorf, Politische Gemeinde (bis 2006)')\
        | (df_clean['GEBIETS_NAME'] == 'Meilen, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Meilen, Politische Gemeinde (bis 2009)')\
        | (df_clean['GEBIETS_NAME'] == 'Oetwil a.d.L., Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Stäfa, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Stäfa, Politische Gemeinde (bis 2014)')\
        | (df_clean['GEBIETS_NAME'] == 'Uetikon am See, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Uetikon am See, Politische Gemeinde (bis 2002)')\
        | (df_clean['GEBIETS_NAME'] == 'Zumikon, Politische Gemeinde')\
        | (df_clean['GEBIETS_NAME'] == 'Zumikon, Politische Gemeinde (bis 2014)')\
        | (df_clean['GEBIETS_NAME'] == 'Zollikon, Politische Gemeinde')
        | (df_clean['GEBIETS_NAME'] == 'Männedorf, Politische Gemeinde')]

# %%
df_meilen.fillna(0)
df_meilen2 = df_meilen.fillna(0)

# %%
df_meilen2
# Out:
#                                        GEBIETS_NAME        1990       1991  \
# 58                   Erlenbach, Politische Gemeinde   1408696.0 -2350345.0
# 84                  Herrliberg, Politische Gemeinde         0.0        0.0
# 85       Herrliberg, Politische Gemeinde (bis 2006)   1049236.0  -541285.0
# 94               Hombrechtikon, Politische Gemeinde         0.0        0.0
# 95    Hombrechtikon, Politische Gemeinde (bis 2009)   4827687.0   993770.0
# 113        Küsnacht, Politische Gemeinde (bis 2018)  10954372.0 -4940106.0
# 121                  Männedorf, Politische Gemeinde         0.0        0.0
# 122       Männedorf, Politische Gemeinde (bis 2006)     -4665.0 -1180563.0
# 127                     Meilen, Politische Gemeinde         0.0        0.0
# 128          Meilen, Politische Gemeinde (bis 2009)  -9832249.0 -9295250.0
# 152              Oetwil a.d.L., Politische Gemeinde    699557.0  -864832.0
# ...

# %%
df_meilen2.loc[84] += df_meilen2.loc[85]
df_meilen2.drop([85], inplace=True)

# %%
df_meilen3 = df_meilen2

# %%
df_meilen3.loc[94] += df_meilen3.loc[95]
df_meilen3.drop([95], inplace=True)

# %%
df_meilen4 = df_meilen3

# %%
df_meilen4.loc[127] += df_meilen4.loc[128]
df_meilen4.drop([128], inplace=True)

# %%
df_meilen5 = df_meilen4

# %%
df_meilen5.loc[121] += df_meilen5.loc[122]
df_meilen5.loc[195] += df_meilen5.loc[196]
df_meilen5.loc[207] += df_meilen5.loc[208]
df_meilen5.loc[244] += df_meilen5.loc[245]

# %%
df_meilen6 = df_meilen5

# %%
df_meilen6
# Out:
#                                           GEBIETS_NAME        1990       1991  \
# 58                      Erlenbach, Politische Gemeinde   1408696.0 -2350345.0
# 84   Herrliberg, Politische GemeindeHerrliberg, Pol...   1049236.0  -541285.0
# 94   Hombrechtikon, Politische GemeindeHombrechtiko...   4827687.0   993770.0
# 113           Küsnacht, Politische Gemeinde (bis 2018)  10954372.0 -4940106.0
# 121  Männedorf, Politische GemeindeMännedorf, Polit...     -4665.0 -1180563.0
# 122          Männedorf, Politische Gemeinde (bis 2006)     -4665.0 -1180563.0
# 127  Meilen, Politische GemeindeMeilen, Politische ...  -9832249.0 -9295250.0
# 152                 Oetwil a.d.L., Politische Gemeinde    699557.0  -864832.0
# 195  Stäfa, Politische GemeindeStäfa, Politische Ge...  -2137704.0 -1055492.0
# 196              Stäfa, Politische Gemeinde (bis 2014)  -2137704.0 -1055492.0
# 207  Uetikon am See, Politische GemeindeUetikon am ...   -701967.0  -580070.0
# ...

# %%
#multipler zeilendrop
df_meilen6.drop([122,196,208,245])
df_meilendef = df_meilen6.drop([122,196,208,245])

# %%
df_meilendef['GEBIETS_NAME'].unique()
# Out:
# array(['Erlenbach, Politische Gemeinde',
#        'Herrliberg, Politische GemeindeHerrliberg, Politische Gemeinde (bis 2006)',
#        'Hombrechtikon, Politische GemeindeHombrechtikon, Politische Gemeinde (bis 2009)',
#        'Küsnacht, Politische Gemeinde (bis 2018)',
#        'Männedorf, Politische GemeindeMännedorf, Politische Gemeinde (bis 2006)',
#        'Meilen, Politische GemeindeMeilen, Politische Gemeinde (bis 2009)',
#        'Oetwil a.d.L., Politische Gemeinde',
#        'Stäfa, Politische GemeindeStäfa, Politische Gemeinde (bis 2014)',
#        'Uetikon am See, Politische GemeindeUetikon am See, Politische Gemeinde (bis 2002)',
#        'Zollikon, Politische Gemeinde',
#        'Zumikon, Politische GemeindeZumikon, Politische Gemeinde (bis 2014)'],
#       dtype=object)

# %%
df_meilendef.replace({"Erlenbach, Politische Gemeinde":"Erlenbach",
                      "Herrliberg, Politische GemeindeHerrliberg, Politische Gemeinde (bis 2006)":"Herrliberg",
                   "Hombrechtikon, Politische GemeindeHombrechtikon, Politische Gemeinde (bis 2009)":"Hombrechtikon",
                      "Küsnacht, Politische Gemeinde (bis 2018)":"Küsnacht",
                      "Männedorf, Politische GemeindeMännedorf, Politische Gemeinde (bis 2006)":"Männedorf",
                   "Meilen, Politische GemeindeMeilen, Politische Gemeinde (bis 2009)":"Meilen",
                   "Oetwil a.d.L., Politische Gemeinde":"Oetwil",
                      "Stäfa, Politische GemeindeStäfa, Politische Gemeinde (bis 2014)":"Stäfa",
                   "Uetikon am See, Politische GemeindeUetikon am See, Politische Gemeinde (bis 2002)":"Uetikon",
                     'Zollikon, Politische Gemeinde':'Zollikon',
                     'Zumikon, Politische GemeindeZumikon, Politische Gemeinde (bis 2014)':'Zumikon'})
df_meilenfin = df_meilendef.replace({"Erlenbach, Politische Gemeinde":"Erlenbach",
                      "Herrliberg, Politische GemeindeHerrliberg, Politische Gemeinde (bis 2006)":"Herrliberg",
                   "Hombrechtikon, Politische GemeindeHombrechtikon, Politische Gemeinde (bis 2009)":"Hombrechtikon",
                      "Küsnacht, Politische Gemeinde (bis 2018)":"Küsnacht",
                      "Männedorf, Politische GemeindeMännedorf, Politische Gemeinde (bis 2006)":"Männedorf",
                   "Meilen, Politische GemeindeMeilen, Politische Gemeinde (bis 2009)":"Meilen",
                   "Oetwil a.d.L., Politische Gemeinde":"Oetwil",
                      "Stäfa, Politische GemeindeStäfa, Politische Gemeinde (bis 2014)":"Stäfa",
                   "Uetikon am See, Politische GemeindeUetikon am See, Politische Gemeinde (bis 2002)":"Uetikon",
                     'Zollikon, Politische Gemeinde':'Zollikon',
                     'Zumikon, Politische GemeindeZumikon, Politische Gemeinde (bis 2014)':'Zumikon'})

# %%
df_meilenfin
# Out:
#       GEBIETS_NAME        1990       1991       1992       1993        1994  \
# 58       Erlenbach   1408696.0 -2350345.0  -528556.0  -685090.0   1863332.0
# 84      Herrliberg   1049236.0  -541285.0  -536646.0   448821.0   5912615.0
# 94   Hombrechtikon   4827687.0   993770.0 -1510410.0   299800.0    319603.0
# 113       Küsnacht  10954372.0 -4940106.0 -2239937.0  4007714.0  11781974.0
# 121      Männedorf     -4665.0 -1180563.0   -87360.0   150170.0     44828.0
# 127         Meilen  -9832249.0 -9295250.0  6286513.0  3347413.0   9412669.0
# 152         Oetwil    699557.0  -864832.0   -89787.0  -171448.0    -24477.0
# 195          Stäfa  -2137704.0 -1055492.0  1017665.0  -382925.0   2436520.0
# 207        Uetikon   -701967.0  -580070.0  -495005.0   -99111.0    320420.0
# 243       Zollikon   8159625.0 -1952680.0  3058126.0  3384129.0   2606911.0
# 244        Zumikon   2632071.0 -3302297.0   683417.0 -1088450.0    640906.0
#
# ...

# %%
df_horgen.at[[97],2018] = -9333122.0
df_horgen.drop([96], inplace=True)
# Out:
# /Users/martinsteinegger/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /Users/martinsteinegger/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
pd.set_option("display.max_columns", 30)

# %%
df_horgen.fillna(0)
df_horgen1 = df_horgen.fillna(0)

# %%
df_horgen1.loc[148] += df_horgen1.loc[147]
df_horgen1.drop([147], inplace=True)

# %%
df_horgen2 = df_horgen1

# %%
df_horgen2
# Out:
#                                           GEBIETS_NAME       1990       1991  \
# 1                                      Adliswil, Stadt   319332.0 -1219798.0
# 97              Horgen, Politische Gemeinde (bis 2017)  1052827.0 -4659837.0
# 108                     Kilchberg, Politische Gemeinde  -699934.0  -644693.0
# 116                  Langnau a.A., Politische Gemeinde  1396626.0 -1404765.0
# 148  Oberrieden, Politische Gemeinde (bis 2009)Ober...  1296423.0  1593860.0
# 171                   Richterswil, Politische Gemeinde        0.0        0.0
# 172        Richterswil, Politische Gemeinde (bis 1997)   133907.0 -1389359.0
# 178                    Rüschlikon, Politische Gemeinde  1490489.0 -3159114.0
# 203                       Thalwil, Politische Gemeinde  3334595.0  2128874.0
# 217                        Wädenswil, Stadt (bis 2018) -3149162.0 -5153598.0
#
#           1992        1993       1994       1995       1996       1997  \
# ...

# %%
df_horgen2.loc[171] += df_horgen2.loc[172]
df_horgen2.drop([172], inplace=True)

# %%
df_horgen2["GEBIETS_NAME"].unique()
# Out:
# array(['Adliswil, Stadt', 'Horgen, Politische Gemeinde (bis 2017)',
#        'Kilchberg, Politische Gemeinde',
#        'Langnau a.A., Politische Gemeinde',
#        'Oberrieden, Politische Gemeinde (bis 2009)Oberrieden, Politische Gemeinde',
#        'Richterswil, Politische GemeindeRichterswil, Politische Gemeinde (bis 1997)',
#        'Rüschlikon, Politische Gemeinde', 'Thalwil, Politische Gemeinde',
#        'Wädenswil, Stadt (bis 2018)'], dtype=object)

# %%
df_horgen2.replace({"Adliswil, Stadt":"Adliswil","Horgen, Politische Gemeinde (bis 2017)":"Horgen",
                   "Kilchberg, Politische Gemeinde":"Kilchberg","Langnau a.A., Politische Gemeinde":"Langnau","Oberrieden, Politische Gemeinde (bis 2009)Oberrieden, Politische Gemeinde":"Oberrieden",
                   "Richterswil, Politische GemeindeRichterswil, Politische Gemeinde (bis 1997)":"Richterswil",
                   "Rüschlikon, Politische Gemeinde":"Rüschlikon","Thalwil, Politische Gemeinde":"Thalwil",
                   "Wädenswil, Stadt (bis 2018)":"Wädenswil"})
# Out:
#     GEBIETS_NAME       1990       1991       1992        1993       1994  \
# 1       Adliswil   319332.0 -1219798.0 -2473458.0  13074084.0  6330146.0
# 97        Horgen  1052827.0 -4659837.0 -4156119.0  -2482936.0 -2281641.0
# 108    Kilchberg  -699934.0  -644693.0    28808.0   -130443.0   882050.0
# 116      Langnau  1396626.0 -1404765.0 -2351166.0    840658.0  -329085.0
# 148   Oberrieden  1296423.0  1593860.0  1284239.0    500511.0  2819685.0
# 171  Richterswil   133907.0 -1389359.0  2021991.0  -1050729.0  7847356.0
# 178   Rüschlikon  1490489.0 -3159114.0 -2983186.0   2641271.0    32737.0
# 203      Thalwil  3334595.0  2128874.0  -786545.0   4911646.0  -428716.0
# 217    Wädenswil -3149162.0 -5153598.0 -1774278.0  -4031571.0  5082468.0
#
#           1995       1996       1997       1998       1999       2000  \
# 1   -5863116.0   144627.0 -4565596.0 -5338432.0 -1147875.0   470115.0
# 97  -3981094.0  2464465.0   467803.0  3378897.0  7243630.0  6323524.0
# ...

# %%
df_horgen3 = df_horgen2.replace({"Adliswil, Stadt":"Adliswil","Horgen, Politische Gemeinde (bis 2017)":"Horgen",
                   "Kilchberg, Politische Gemeinde":"Kilchberg","Langnau a.A., Politische Gemeinde":"Langnau","Oberrieden, Politische Gemeinde (bis 2009)Oberrieden, Politische Gemeinde":"Oberrieden",
                   "Richterswil, Politische GemeindeRichterswil, Politische Gemeinde (bis 1997)":"Richterswil",
                   "Rüschlikon, Politische Gemeinde":"Rüschlikon","Thalwil, Politische Gemeinde":"Thalwil",
                   "Wädenswil, Stadt (bis 2018)":"Wädenswil"})

# %%
df_horgen3
# Out:
#     GEBIETS_NAME       1990       1991       1992        1993       1994  \
# 1       Adliswil   319332.0 -1219798.0 -2473458.0  13074084.0  6330146.0
# 97        Horgen  1052827.0 -4659837.0 -4156119.0  -2482936.0 -2281641.0
# 108    Kilchberg  -699934.0  -644693.0    28808.0   -130443.0   882050.0
# 116      Langnau  1396626.0 -1404765.0 -2351166.0    840658.0  -329085.0
# 148   Oberrieden  1296423.0  1593860.0  1284239.0    500511.0  2819685.0
# 171  Richterswil   133907.0 -1389359.0  2021991.0  -1050729.0  7847356.0
# 178   Rüschlikon  1490489.0 -3159114.0 -2983186.0   2641271.0    32737.0
# 203      Thalwil  3334595.0  2128874.0  -786545.0   4911646.0  -428716.0
# 217    Wädenswil -3149162.0 -5153598.0 -1774278.0  -4031571.0  5082468.0
#
#           1995       1996       1997       1998       1999       2000  \
# 1   -5863116.0   144627.0 -4565596.0 -5338432.0 -1147875.0   470115.0
# 97  -3981094.0  2464465.0   467803.0  3378897.0  7243630.0  6323524.0
# ...

# %%
df_horgen3.set_index("GEBIETS_NAME",inplace=True)
df_meilenfin.set_index("GEBIETS_NAME",inplace=True)

# %%
df_horgen3
# Out:
#                    1990       1991       1992        1993       1994  \
# GEBIETS_NAME
# Adliswil       319332.0 -1219798.0 -2473458.0  13074084.0  6330146.0
# Horgen        1052827.0 -4659837.0 -4156119.0  -2482936.0 -2281641.0
# Kilchberg     -699934.0  -644693.0    28808.0   -130443.0   882050.0
# Langnau       1396626.0 -1404765.0 -2351166.0    840658.0  -329085.0
# Oberrieden    1296423.0  1593860.0  1284239.0    500511.0  2819685.0
# Richterswil    133907.0 -1389359.0  2021991.0  -1050729.0  7847356.0
# Rüschlikon    1490489.0 -3159114.0 -2983186.0   2641271.0    32737.0
# Thalwil       3334595.0  2128874.0  -786545.0   4911646.0  -428716.0
# Wädenswil    -3149162.0 -5153598.0 -1774278.0  -4031571.0  5082468.0
#
#                    1995       1996       1997       1998       1999  \
# GEBIETS_NAME
# Adliswil     -5863116.0   144627.0 -4565596.0 -5338432.0 -1147875.0
# Horgen       -3981094.0  2464465.0   467803.0  3378897.0  7243630.0
# ...

# %%
df_horgen3.swapaxes("index", "columns")
df_hoplot3 = df_horgen3.swapaxes("index", "columns")

# %%
df_meilenfin.swapaxes("index", "columns")
df_meplot = df_meilenfin.swapaxes("index", "columns")
df_meplot
# Out:
# GEBIETS_NAME  Erlenbach  Herrliberg  Hombrechtikon    Küsnacht  Männedorf  \
# 1990          1408696.0   1049236.0      4827687.0  10954372.0    -4665.0
# 1991         -2350345.0   -541285.0       993770.0  -4940106.0 -1180563.0
# 1992          -528556.0   -536646.0     -1510410.0  -2239937.0   -87360.0
# 1993          -685090.0    448821.0       299800.0   4007714.0   150170.0
# 1994          1863332.0   5912615.0       319603.0  11781974.0    44828.0
# 1995          1425346.0    634906.0     -1157703.0   2039404.0   500559.0
# 1996          -526399.0   -108462.0     -1276107.0   7308394.0   729316.0
# 1997          1082846.0   4679435.0        61452.0  11516798.0  -992605.0
# 1998          5958277.0   7361388.0     -1209890.0  15069262.0    45107.0
# 1999          4962168.0   8605867.0      1573375.0  22769318.0  3484305.0
# 2000          9369763.0   4172952.0       799877.0  37874819.0  3406257.0
# 2001          7815048.0  -1013850.0       643765.0 -13297382.0  1250576.0
# ...

# %%
df_hoplot3.plot(figsize=(15,10), title="Bugets Gemeinden Bezirk Horgen, 1990 bis 2018")

# %%
fig = plt.figure(figsize=(12,3))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
df_hoplot3['Adliswil'].plot(kind='bar',title="Adliswil", ax=ax1)
df_hoplot3['Horgen'].plot(kind='bar',title="Horgen", ax=ax2)

# %%
axes = df_hoplot3.plot(kind='bar',subplots=True,layout=(7, 4), sharey=True, figsize=(20,25))

axes[0,0].xaxis.set_major_locator(ticker.NullLocator())
axes[0,0].xaxis.set_minor_locator(ticker.NullLocator())

# %%
axes = df_meplot.plot(kind='bar',subplots=True,layout=(7, 4), sharey=True, figsize=(20,25))

axes[0,0].xaxis.set_major_locator(ticker.NullLocator())
axes[0,0].xaxis.set_minor_locator(ticker.NullLocator())

# %%
path = 'Erstsprache/b.csv'

# %%
df_horgen3.to_csv(path, index=True)

# %%
path = 'Bilanz Winterthur/budgetmeilen.csv'

# %%
df_meilenfin.to_csv(path, index=True)
